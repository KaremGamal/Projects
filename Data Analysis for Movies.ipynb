# %% [markdown]
# # *DATA ANALYSIS FOR MOVIES*

# %% [markdown]
# Data downloaded from Kaggle. Link for data:  https://www.kaggle.com/datasets/danielgrijalvas/movies

# %% [markdown]
# **The project's goal is to determine the relationship between the budget and other aspects. and then visualize the data using seaborn and matplotlip. So, first and foremost, I will thoroughly comprehend the data. After that, I'll clean the data and do some data exploration. Finally, look for correlations and visualize the results.**

# %% [markdown]
# ## Steps:
#
# ###  - Understanding the data
# ###  - Clean&Explore data
# ###  - Find the correlation between gross and other features

# %%
#Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12,8] #Adjusts the configuration of the plots we will create

# %%
# Download data
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_b513d501b0314f9ca0a4b43814f413b8 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='5tNqIFb9sKb-r9oyT-EPiwcNSYclB1ZqInuVdX-Kq_ho',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

body = client_b513d501b0314f9ca0a4b43814f413b8.get_object(Bucket='dataanalysisformovies-donotdelete-pr-jdlmyl76jsdbd4',Key='movies.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )


df = pd.read_csv(body)

# %% [markdown]
# ### - Understanding the data

# %%
#Read data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.tail()
# Out:
#                name rating   genre  year                          released  \
# 7663   More to Life    NaN   Drama  2020  October 23, 2020 (United States)
# 7664    Dream Round    NaN  Comedy  2020  February 7, 2020 (United States)
# 7665  Saving Mbango    NaN   Drama  2020         April 27, 2020 (Cameroon)
# 7666   It's Just Us    NaN   Drama  2020   October 1, 2020 (United States)
# 7667      Tee em el    NaN  Horror  2020   August 19, 2020 (United States)
#
#       score  votes       director         writer              star  \
# 7663    3.1   18.0  Joseph Ebanks  Joseph Ebanks      Shannon Bond
# 7664    4.7   36.0   Dusty Dukatz    Lisa Huston  Michael Saquella
# 7665    5.7   29.0   Nkanya Nkwai   Lynno Lovert      Onyama Laura
# 7666    NaN    NaN  James Randall  James Randall     Christina Roz
# 7667    5.7    7.0   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso
#
#             country   budget  gross                    company  runtime
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
# Sort data in descending order by budget
df = df.sort_values(by = ['budget'],ascending=False)
df.head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score   votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %% [markdown]
# After I understand data I guess that there are high correlations between budget and company with gross

# %% [markdown]
# ###  - Clean&Explore data

# %%
# I'm seeing if there are any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    
    print('{}-{}%'.format(col,pct_missing))
# Out:
# name-0.0%
# rating-0.010041731872717789%
# genre-0.0%
# year-0.0%
# released-0.0002608242044861763%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0003912363067292645%
# star-0.00013041210224308815%
# country-0.0003912363067292645%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.002217005738132499%
# runtime-0.0005216484089723526%

# %%
# Data size
df.shape
# Out:
# (7668, 15)

# %%
# Missing data in each column
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Drop null data with 'any'
df.dropna(how = 'any').shape
# Out:
# (5421, 15)

# %%
# Drop null data with 'all'
df.dropna(how = 'all').shape
# Out:
# (7668, 15)

# %%
# Finally I will choose 'any' to cleaning null values
df.dropna(how = 'any',inplace = True)
df.shape
# Out:
# (5421, 15)

# %%
# Data types for the columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data type of columns
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

df['votes'] = df['votes'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %%
# Let's look at the data 
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df['company'].sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 332                                      Zoetrope Studios
# 724                                      Zoetrope Studios
# 520                                      Zoetrope Studios
# 146                                      Zoetrope Studios
# 352                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 4297                              Zentropa Entertainments
# 3698                              Zentropa Entertainments
# 4829                              Zentropa Entertainments
# ...

# %%
df['company'].sort_values(ascending=False).count()
# Out:
# 5421

# %%
# Drop all duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 520                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 4829                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
df['company'].drop_duplicates().sort_values(ascending=False).count()
# Out:
# 1475

# %% [markdown]
# ### Find Correlation between Gross and other Features

# %% [markdown]
# There are different types of correlations( 'pearson','kendall','spearman') and I will use all of them here

# %%
# Correlation for numerical data
df.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
df.corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
# Scatter plot with budget vs gross
plt.scatter(x = df['budget'], y= df['gross'])

plt.title('Gross vs Budger')
plt.xlabel('Budget')
plt.ylabel('Gross')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot budget vs gross using seaborn
sns.regplot(x ='budget', y='gross',data= df, scatter_kws = {'color':'green'}, line_kws= {'color':'yellow'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Visulise correlation using the heatmap for numerical data
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix,annot =True)
plt.title('Correlation Matrix For Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
# Let's look again at the data 
df.head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score   votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %%
# Convert categorical data to numerical data
df_numerized= df
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score   votes  director  writer  \
# 7445   388       5      0  2019       137    8.4  903000       105     513
# 7244   389       5      0  2018       145    8.4  897000       105     513
# 7075  3644       5      0  2017       500    7.0  581000      1589    2487
# 7066  2124       5      0  2017      1996    6.1  418000      2057    1402
# 5060  2987       5      0  2007      1844    7.1  608000       674    2927
#
#       star  country     budget       gross  company  runtime
# 7445  1470       47  356000000  2797501328      983      181
# 7244  1470       47  321000000  2048359754      983      149
# 7075   356       47  317000000  1332698830     1423      152
# 7066   140       47  300000000   657926987     1426      120
# 5060   889       47  300000000   960996492     1423      169

# %%
# This is the correlation for all the data 
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs =correlation_mat.unstack()
corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.029234
#           genre       0.010996
#           year        0.025542
#           released   -0.006152
#           score       0.014450
#           votes       0.012615
#           director    0.015246
#           writer      0.012880
#           star       -0.006882
#           country    -0.025490
#           budget      0.023392
#           gross       0.005639
#           company     0.021697
#           runtime     0.010850
# rating    name       -0.029234
#           rating      1.000000
#           genre       0.147796
#           year        0.019499
#           released    0.018083
#           score       0.065983
#           votes       0.006031
#           director    0.014656
#           writer     -0.003149
#           star        0.009196
#           country     0.008230
#           budget     -0.203946
#           gross      -0.181906
#           company    -0.092357
#           runtime     0.140792
# ...

# %%
#Visulise correlation using the heatmap for all data

correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix,annot =True)
plt.title('Correlation Matrix For Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %% [markdown]
# **As we saw the highest correlation for gross was with budget and votes**

# %% [markdown]
# ## END OF THE PROJECT
# ## THANKS
